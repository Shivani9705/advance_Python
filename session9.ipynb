# %% [markdown]
# # Multithreading = multiple threads

# %%
def print_message():
    print("Welcome to ETLHIVE!!")

# %%
import threading

t1=threading.Thread(target=print_message)

# %%
t1.start()
# Out:
# Welcome to ETLHIVE!!

# %%
# Example 2

# %%
def calculate_square(n):
    print(f"the square of number {n} is {n*n}")

# %%
t2=threading.Thread(target=calculate_square,args=(5,))
t2.start()
# Out:
# the square of number 5 is 25

# %%
l1=[10,20,2,3,5,7,8,9,11,22]

# %%
for i in l1:
    t2=threading.Thread(target=calculate_square,args=(i,))
    t2.start()
# Out:
# the square of number 10 is 100
# the square of number 20 is 400
# the square of number 2 is 4
# the square of number 3 is 9
# the square of number 5 is 25
# the square of number 7 is 49
# the square of number 8 is 64
# the square of number 9 is 81
# the square of number 11 is 121
# the square of number 22 is 484

# %%
# create threading for downloading a file from server

# %%
message="India is my country"

# %%
len(message)
# Out:
# 19

# %%
m=message.split(' ')
m
# Out:
# ['India', 'is', 'my', 'country']

# %%
len(m)
# Out:
# 4

# %%
lnk="https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/data.csv"
len(lnk)
l=lnk.split("/")
len(l)
# Out:
# 8

# %%
l[-1]
# Out:
# 'data.csv'

# %%
import urllib.request   
def download_file(lnk):
    file_name=lnk.split("/")[-1]
    print("file is downloading.........")
    path="C:/Users/admin/Downloads/"+file_name
    urllib.request.urlretrieve(lnk,path)
    print(f"{file_name} is downloaded")

# %%
download_file("https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/data.csv")
# Out:
# file is downloading.........
# data.csv is downloaded

# %%
lst=[
    "https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/data.csv",
"https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/test.csv",
"https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/train.csv"
]

# %%
for i in lst:
    th=threading.Thread(target=download_file,args=(i,))
    th.start()
# Out:
# file is downloading.........
# file is downloading.........
# file is downloading.........
# test.csv is downloaded
# train.csv is downloaded
# data.csv is downloaded
